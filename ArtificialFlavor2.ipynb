# %% [markdown]
# <a href="https://colab.research.google.com/github/abiaggi/artificial-flavor-gpt2/blob/main/ArtificialFlavor2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
import sys
import requests
from tqdm import tqdm


model = "117M"

subdir = os.path.join('models', model)
if not os.path.exists(subdir):
    os.makedirs(subdir)
subdir = subdir.replace('\\','/') # needed for Windows

for filename in ['checkpoint','encoder.json','hparams.json','model.ckpt.data-00000-of-00001', 'model.ckpt.index', 'model.ckpt.meta', 'vocab.bpe']:

    r = requests.get("https://openaipublic.blob.core.windows.net/gpt-2/" + subdir + "/" + filename, stream=True)

    with open(os.path.join(subdir, filename), 'wb') as f:
        file_size = int(r.headers["content-length"])
        chunk_size = 1000
        with tqdm(ncols=100, desc="Fetching " + filename, total=file_size, unit_scale=True) as pbar:
            # 1k for chunk_size, since Ethernet packet size is around 1500 bytes
            for chunk in r.iter_content(chunk_size=chunk_size):
                f.write(chunk)
                pbar.update(chunk_size)
# Out:
# Fetching checkpoint: 1.00kit [00:00, 545kit/s]
# Fetching encoder.json: 1.04Mit [00:00, 2.38Mit/s]
# Fetching hparams.json: 1.00kit [00:00, 333kit/s]
# Fetching model.ckpt.data-00000-of-00001: 498Mit [00:20, 24.1Mit/s]
# Fetching model.ckpt.index: 6.00kit [00:00, 1.73Mit/s]
# Fetching model.ckpt.meta: 472kit [00:00, 1.24Mit/s]
# Fetching vocab.bpe: 457kit [00:00, 1.28Mit/s]

# %%
pip install tensorflow==1.15
# Out:
# ...
#      |████████████████████████████████| 412.3MB 41kB/s
# ...
#      |████████████████████████████████| 3.8MB 49.6MB/s
# ...
#      |████████████████████████████████| 51kB 7.2MB/s
# ...
#      |████████████████████████████████| 512kB 50.1MB/s
# ...
#   Created wheel for gast: filename=gast-0.2.2-cp37-none-any.whl size=7540 sha256=eb6bd2d4b34eaf004399c414f82b0a79c0d5dfc74441b2a50bfa23158ab4b532
#   Stored in directory: /root/.cache/pip/wheels/5c/2e/7e/a1d4d4fcebe6c381f378ce7743a3ced3699feb89bcfbdadadd
# Successfully built gast
# ERROR: tensorflow-probability 0.12.1 has requirement gast>=0.3.2, but you'll have gast 0.2.2 which is incompatible.
# ...
#   Found existing installation: gast 0.3.3
#     Uninstalling gast-0.3.3:
#       Successfully uninstalled gast-0.3.3
#   Found existing installation: tensorboard 2.4.1
#     Uninstalling tensorboard-2.4.1:
#       Successfully uninstalled tensorboard-2.4.1
#   Found existing installation: tensorflow-estimator 2.4.0
#     Uninstalling tensorflow-estimator-2.4.0:
# ...

# %%
pip install gpt2-client
# Out:
# ...
#   Created wheel for gpt2-client: filename=gpt2_client-2.1.5-cp37-none-any.whl size=16434 sha256=c8accaf2c10fac025c179b59a975222aaf5cba8178474256affcd97ccf2cca0d
#   Stored in directory: /root/.cache/pip/wheels/47/03/99/deadcb428f1b3c591edb8d6a2ac0136bb4326a266364b72153
# ...
#   Created wheel for gpt-2-simple: filename=gpt_2_simple-0.7.2-cp37-none-any.whl size=23621 sha256=937930bff8c62bdc36a1995fbb425421c47e15c4560bbd86a4947aa84ac1fa55
#   Stored in directory: /root/.cache/pip/wheels/68/1d/15/c87a4302a6c7273ce1b4f282bec3c6877fb2f521535d87d30f
# Successfully built gpt2-client gpt-2-simple
# ...

# %%
from gpt2_client import GPT2Client

gpt2 = GPT2Client('117M')  # This could also be `345M`, `774M`, or `1558M`. Rename `save_dir` to anything.
gpt2.load_model(force_download=False)  # Use cached versions if available.
# Out:
# WARNING:tensorflow:
# The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
#   * https://github.com/tensorflow/community/blob/master/rfcs/20180907-contrib-sunset.md
#   * https://github.com/tensorflow/addons
#   * https://github.com/tensorflow/io (for I/O related ops)
# If you depend on functionality not listed there, please file an issue.
#
# Loading checkpoint                             File already exists
# Loading encoder.json                           File already exists
# Loading hparams.json                           File already exists
# Loading model.ckpt.data-00000-of-00001         File already exists
# Loading model.ckpt.index                       File already exists
# Loading model.ckpt.meta                        File already exists
# Loading vocab.bpe                              File already exists

# %% [markdown]
# IMPORT THE MODELS MANUALLY, SINCE THEY ARE BROKEN!!!!!

# %%
corpus = "cards.txt"
custom = gpt2.finetune(corpus, return_text=True)
# Out:
# Loading checkpoint models/117M/model.ckpt
# 100%|██████████| 1/1 [00:00<00:00,  6.88it/s]
# Loading dataset...
# dataset has 28527 tokens
# Training...
# [1 | 9.12] loss=1.62 avg=1.62
# [2 | 11.29] loss=1.45 avg=1.53
# [3 | 13.48] loss=1.44 avg=1.50
# [4 | 15.67] loss=1.38 avg=1.47
# [5 | 17.86] loss=1.21 avg=1.42
# [6 | 20.06] loss=1.15 avg=1.37
# [7 | 22.27] loss=1.18 avg=1.34
# [8 | 24.49] loss=1.16 avg=1.32
# [9 | 26.71] loss=1.13 avg=1.30
# [10 | 28.94] loss=0.99 avg=1.26
# [11 | 31.18] loss=1.06 avg=1.24
# [12 | 33.42] loss=0.96 avg=1.22
# [13 | 35.68] loss=1.00 avg=1.20
# [14 | 37.93] loss=0.90 avg=1.18
# [15 | 40.20] loss=0.81 avg=1.15
# [16 | 42.47] loss=0.89 avg=1.13
# [17 | 44.75] loss=0.87 avg=1.12
# [18 | 47.04] loss=0.90 avg=1.10
# [19 | 49.32] loss=0.75 avg=1.08
# [20 | 51.62] loss=0.84 avg=1.07
# [21 | 53.93] loss=0.74 avg=1.05
# [22 | 56.25] loss=0.77 avg=1.04
# [23 | 58.57] loss=0.77 avg=1.03
# [24 | 60.91] loss=0.68 avg=1.01
# [25 | 63.27] loss=0.83 avg=1.00
# ...

# %%
print(custom)
# Out:
# ["Fire! Fire! Hey! Is that you? No, it's not that. It's me. It's you.\nI have seen much from the back of my dromad, most of it terribly wrong. The more I look, the more I see the truth: the world is falling apart. I am a philosopher's throwback, a fool's coin.\nTo visit the sky requires bravery, and thought, and little else. To master the sky requires the binding of its masters, who ultimately will decide whether they are bound or free.\nThe corruption Soltari hid in the catacombs of Crovax was so foul that all hell broke down in their bloodless soil.\nThe price of prophecy is a price we pay as well as freedom.\nWhat the God\nMany have heard it say that the God\nThe God\nDon't let your mind wander for long when you have the chance to use its muscles.\nThe God\nMy destiny is to save others so that they may realize their greatest dreams can be achieved only in the home where all are present.\nThe Godcrafters are not the only religious people in Velis Vel.\nI will build monuments that w
# ...
